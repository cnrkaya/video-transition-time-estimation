# %% [markdown]
# This notebook includes, preparing the dataset for training and applying the regression techniques contained in scikit-learn library to estimate video transcoding time.
#
#
# > Dataset and detailed information: https://archive.ics.uci.edu/ml/datasets/Online+Video+Characteristics+and+Transcoding+Time+Dataset

# %% [markdown]
# ## 1.Colab Environment Settings and Download the Data Set

# %%
#mount google drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
#check the directory
# !ls "/gdrive/My Drive/video-transition-time-estimation/"
# Out:
#  blogData_train.csv		   README.txt
# 'car data.csv'			   transcoding_mesurment.tsv
# 'CAR DETAILS FROM CAR DEKHO.csv'   Untitled0.ipynb
#  car_price_prediction.ipynb	   youtube_videos.tsv
#  online_video_dataset.zip

# %%
#set as a current directory
import os
os.chdir("/gdrive/My Drive/video-transition-time-estimation/")

# %%
#download the data set
#!curl https://archive.ics.uci.edu/ml/machine-learning-databases/00335/online_video_dataset.zip --output online_video_dataset.zip

# %%
#unzip
# !unzip online_video_dataset.zip
# Out:
# Archive:  online_video_dataset.zip
# replace README.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace transcoding_mesurment.tsv? [y]es, [n]o, [A]ll, [N]one, [r]ename: no
# replace youtube_videos.tsv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %% [markdown]
# ## 2. Data Pre-Process

# %% [markdown]
# ###2.1. Import and Analyze the Data

# %%
#import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("transcoding_mesurment.tsv",sep='\t')
df.head()
# Out:
#             id   duration  codec  width  ...  o_width  o_height   umem  utime
# 0  04t6-jw9czg  130.35667  mpeg4    176  ...      176       144  22508  0.612
# 1  04t6-jw9czg  130.35667  mpeg4    176  ...      320       240  25164  0.980
# 2  04t6-jw9czg  130.35667  mpeg4    176  ...      480       360  29228  1.216
# 3  04t6-jw9czg  130.35667  mpeg4    176  ...      640       480  34316  1.692
# 4  04t6-jw9czg  130.35667  mpeg4    176  ...     1280       720  58528  3.456
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#            duration         width  ...           umem         utime
# count  68784.000000  68784.000000  ...   68784.000000  68784.000000
# mean     286.413921    624.934171  ...  228224.717900      9.996355
# std      287.257650    463.169069  ...   97430.878373     16.107429
# min       31.080000    176.000000  ...   22508.000000      0.184000
# 25%      106.765000    320.000000  ...  216820.000000      2.096000
# 50%      239.141660    480.000000  ...  219480.000000      4.408000
# 75%      379.320000    640.000000  ...  219656.000000     10.433000
# max    25844.086000   1920.000000  ...  711824.000000    224.574000
#
# [8 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68784 entries, 0 to 68783
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           68784 non-null  object
#  1   duration     68784 non-null  float64
#  2   codec        68784 non-null  object
#  3   width        68784 non-null  int64
#  4   height       68784 non-null  int64
#  5   bitrate      68784 non-null  int64
#  6   framerate    68784 non-null  float64
#  7   i            68784 non-null  int64
#  8   p            68784 non-null  int64
#  9   b            68784 non-null  int64
#  10  frames       68784 non-null  int64
#  11  i_size       68784 non-null  int64
#  12  p_size       68784 non-null  int64
#  13  b_size       68784 non-null  int64
#  14  size         68784 non-null  int64
#  15  o_codec      68784 non-null  object
#  16  o_bitrate    68784 non-null  int64
#  17  o_framerate  68784 non-null  float64
#  18  o_width      68784 non-null  int64
#  19  o_height     68784 non-null  int64
#  20  umem         68784 non-null  int64
#  21  utime        68784 non-null  float64
# dtypes: float64(4), int64(15), object(3)
# memory usage: 11.5+ MB

# %% [markdown]
# ### 2.2. Correlation

# %%
corrTable = df.corr(method='pearson')
a = corrTable['utime'].sort_values(ascending=False).to_frame()
cm = sns.light_palette("green",as_cmap=True)
a.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_3564957a_13c9_11eb_ab0b_0242ac1c0002row0_col0{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row1_col0{
#             background-color:  #4fa74f;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row2_col0{
#             background-color:  #70b770;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row3_col0{
#             background-color:  #71b771;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row4_col0,#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row5_col0{
#             background-color:  #c8e2c8;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row6_col0{
#             background-color:  #cde5cd;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row7_col0{
#             background-color:  #cee5ce;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row8_col0{
#             background-color:  #d4e8d4;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row9_col0,#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row10_col0{
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row11_col0{
#             background-color:  #d9ead9;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row12_col0{
#             background-color:  #ddecdd;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row13_col0,#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row14_col0{
#             background-color:  #e4f0e4;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row15_col0{
#             background-color:  #e8f2e8;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row16_col0,#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row17_col0{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_3564957a_13c9_11eb_ab0b_0242ac1c0002row18_col0{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >utime</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row0" class="row_heading level0 row0" >utime</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row0_col0" class="data row0 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row1" class="row_heading level0 row1" >umem</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row1_col0" class="data row1 col0" >0.663301</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row2" class="row_heading level0 row2" >o_width</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row2_col0" class="data row2 col0" >0.523388</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row3" class="row_heading level0 row3" >o_height</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row3_col0" class="data row3 col0" >0.519649</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row4" class="row_heading level0 row4" >o_bitrate</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row4_col0" class="data row4 col0" >0.155479</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row5" class="row_heading level0 row5" >bitrate</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row5_col0" class="data row5 col0" >0.155200</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row6" class="row_heading level0 row6" >width</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row6_col0" class="data row6 col0" >0.129861</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row7" class="row_heading level0 row7" >height</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row7_col0" class="data row7 col0" >0.128479</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row8" class="row_heading level0 row8" >o_framerate</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row8_col0" class="data row8 col0" >0.104043</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row9" class="row_heading level0 row9" >p_size</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row9_col0" class="data row9 col0" >0.097644</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row10" class="row_heading level0 row10" >size</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row10_col0" class="data row10 col0" >0.097096</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row11" class="row_heading level0 row11" >framerate</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row11_col0" class="data row11 col0" >0.079336</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row12" class="row_heading level0 row12" >i_size</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row12_col0" class="data row12 col0" >0.064711</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row13" class="row_heading level0 row13" >p</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row13_col0" class="data row13 col0" >0.033201</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row14" class="row_heading level0 row14" >frames</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row14_col0" class="data row14 col0" >0.033115</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row15" class="row_heading level0 row15" >i</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row15_col0" class="data row15 col0" >0.018489</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row16" class="row_heading level0 row16" >duration</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row16_col0" class="data row16 col0" >0.005533</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row17" class="row_heading level0 row17" >b</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row17_col0" class="data row17 col0" >0.005140</td>
#             </tr>
#             <tr>
#                         <th id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002level0_row18" class="row_heading level0 row18" >b_size</th>
#                         <td id="T_3564957a_13c9_11eb_ab0b_0242ac1c0002row18_col0" class="data row18 col0" >nan</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 2.3. Define Target and Features

# %%
target = df[['utime']]

# %%
# drop the target column and the columns with low correlation (< 0.05)
features = df.drop(columns = ['utime','b_size','b','duration','i','frames','p','id','o_codec'])
features.head()
# Out:
#    codec  width  height  bitrate  ...  o_framerate  o_width  o_height   umem
# 0  mpeg4    176     144    54590  ...         12.0      176       144  22508
# 1  mpeg4    176     144    54590  ...         12.0      320       240  25164
# 2  mpeg4    176     144    54590  ...         12.0      480       360  29228
# 3  mpeg4    176     144    54590  ...         12.0      640       480  34316
# 4  mpeg4    176     144    54590  ...         12.0     1280       720  58528
#
# [5 rows x 13 columns]

# %% [markdown]
# ### 2.4. One hot encoding for codec column

# %%
features['codec'].value_counts()
# Out:
# h264     31545
# vp8      18387
# mpeg4    12012
# flv       6840
# Name: codec, dtype: int64

# %%
features= pd.get_dummies(features, columns=['codec'])
features.head()
# Out:
#    width  height  bitrate  ...  codec_h264  codec_mpeg4  codec_vp8
# 0    176     144    54590  ...           0            1          0
# 1    176     144    54590  ...           0            1          0
# 2    176     144    54590  ...           0            1          0
# 3    176     144    54590  ...           0            1          0
# 4    176     144    54590  ...           0            1          0
#
# [5 rows x 16 columns]

# %% [markdown]
# ### 2.5. Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(features)
print("Feture Matrix X with shape:",X.shape,"\n",X)

Y = scaler.fit_transform(target)
print("\nTarget Array Y with shape:",Y.shape,"\n",Y)
# Out:
# Feture Matrix X with shape: (68784, 16)
#  [[0.         0.         0.00606371 ... 0.         1.         0.        ]
#  [0.         0.         0.00606371 ... 0.         1.         0.        ]
#  [0.         0.         0.00606371 ... 0.         1.         0.        ]
#  ...
#  [0.08256881 0.1025641  0.04605738 ... 0.         0.         1.        ]
#  [0.63302752 0.61538462 0.37258851 ... 1.         0.         0.        ]
#  [0.         0.         0.00614928 ... 0.         1.         0.        ]]
#
# Target Array Y with shape: (68784, 1)
#  [[0.00190739]
#  [0.0035474 ]
#  [0.00459914]
#  ...
#  [0.00253131]
#  [0.02344133]
#  [0.01288827]]

# %% [markdown]
# ###2.6. Train and Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(features, target,test_size = 0.3, random_state=0)

scores = dict()  #dictionary for storing test scores

# %% [markdown]
# ##3. Implementing Regression Techniques

# %% [markdown]
# ###3.1. Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train,y_train)
lr_score = lr.score(x_test,y_test)

print("Linear Regression Score:{:.4f}".format(lr_score) )
scores['lr'] = lr_score
# Out:
# Linear Regression Score:0.5727

# %% [markdown]
# ###3.2. Polynomial Regression

# %%
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures


poly = PolynomialFeatures(degree=2)
train_x_poly = poly.fit_transform(x_train)

pr = linear_model.LinearRegression()
pr.fit(train_x_poly, y_train)

x_test_poly = poly.fit_transform(x_test)
pr_score = pr.score(x_test_poly,y_test)

print("Polynomial Regression Score:{:.4f}".format(pr_score) )
scores['pr'] = pr_score
# Out:
# Polynomial Regression Score:0.3877

# %% [markdown]
# ###3.3. Ridge Regression

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=1.0)
rr.fit(x_train, y_train)
rr_score = rr.score(x_test,y_test)

print("Ridge Regression Score:{:.4f}".format(rr_score) )
scores['rr'] = rr_score
# Out:
# Ridge Regression Score:0.5727
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.4794e-21): result may not be accurate.
#   overwrite_a=True).T

# %% [markdown]
# ###3.4. K Neighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
neighbors = range(1, 10)

training_scores = []
test_scores = []
for n_neighbors in neighbors:
    knn = KNeighborsRegressor(n_neighbors=n_neighbors).fit(x_train, y_train)
    training_scores.append(knn.score(x_train, y_train))
    test_scores.append(knn.score(x_test, y_test))

# %%
plt.figure()
plt.plot(neighbors, training_scores, label="training scores")
plt.plot(neighbors, test_scores, label="test scores")
plt.ylabel("accuracy")
plt.xlabel("n_neighbors")
plt.legend()

# %%
knn = KNeighborsRegressor(n_neighbors=3)
knn.fit(x_train, y_train)
knn_score = knn.score(x_test,y_test)

print("K Neighbors Regressor Score:{:.4f}".format(knn_score) )
scores['knn'] = knn_score
# Out:
# K Neighbors Regressor Score:0.7640

# %% [markdown]
# ###3.5. SVR

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train, y_train)   #It may take some time
svr_score = knn.score(x_test,y_test)

print("SVR Score:{:.4f}".format(svr_score) )
scores['svr'] = svr_score
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR Score:0.7640

# %% [markdown]
# ###3.6. Stochastic Gradient Descent Regressor

# %%
from sklearn.linear_model import SGDRegressor
sgd = SGDRegressor()
sgd.fit(x_train, y_train)
sgd_score = sgd.score(x_test,y_test)

print("SGD Regressor Score:{:.4f}".format(sgd_score) )
scores['sgd'] = sgd_score
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGD Regressor Score:-142253276017248646187752108631724587304894857216.0000
# -1.4225327601724865e+47

# %% [markdown]
# ###3.7. Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
dtr_score = dtr.score(x_test,y_test)

print("Decision Tree Regressor Score:{:.4f}".format(dtr_score) )
scores['dtr'] = dtr_score
# Out:
# Decision Tree Regressor Score:0.7113

# %% [markdown]
# ###3.8. Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(x_train, y_train.values.ravel())
rfr_score = rfr.score(x_test,y_test)

print("Random Forest Regressor Score:{:.4f}".format(rfr_score) )
scores['rfr'] = rfr_score
# Out:
# Random Forest Regressor Score:0.7848

# %% [markdown]
# ###3.9. Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(x_train, y_train.values.ravel())
gbr_score = gbr.score(x_test,y_test)

print("Gradient Boosting Regressor Score:{:.4f}".format(gbr_score) )
scores['gbr'] = gbr_score
# Out:
# Gradient Boosting Regressor Score:0.8309

# %% [markdown]
# ###3.10. XG Boost Regressor

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor(silent=True)
xgb.fit(x_train,y_train)
xgb_score = xgb.score(x_test,y_test)

print("XG Boost Regressor Score:{:.4f}".format(xgb_score) )
scores['xgb'] = xgb_score
# Out:
# XG Boost Regressor Score:0.8302

# %% [markdown]
# ###3.11. Extra Tree Regressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr = ExtraTreesRegressor()
etr.fit(x_train, y_train.values.ravel())
etr_score = etr.score(x_test,y_test)

print("Exra Tree Regressor Score:{:.4f}".format(etr_score) )
scores['etr'] = etr_score
# Out:
# Exra Tree Regressor Score:0.7199

# %% [markdown]
# ###3.12. Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor
vr = VotingRegressor(estimators=[('rfr', rfr), ('gbr', gbr), ('xgb', xgb)])
vr.fit(x_train,y_train.values.ravel())
vr_score = vr.score(x_test,y_test)

print("Voting Regressor Score:{:.4f}".format(vr_score) )
scores['vr'] = vr_score
# Out:
# Voting Regressor Score:0.8303
